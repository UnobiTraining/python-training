# %% [markdown]
# # Hello Notebook
#
# This is a small demo notebook for the Unobi Training Jupyter setup lesson.

# %%
print("Hello World")

# %%
name = "Unobi Training"
print(f"Welcome to {name}!")
